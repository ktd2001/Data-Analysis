# %% [markdown]
# Keiana Dunn
# Week 13
# 5/13/19
# A demonstration of overfitting
# with a simple polynomial fit
# (not a neural network!!)

# %%
# import libraries that are required
import numpy as np
import sys
import matplotlib.pyplot as plt

# Load data from file into N by 2 numpy array
filename = "abalone.data.txt"
X = np.loadtxt( filename, delimiter=',', usecols=(2,4) )

# Put first column into N by 1 array called diameter
# and second column into N by 1 array called mass_observed
diameter = X[:,0]
mass_observed = X[:,1]

# I don't want to use all the data so I use the numpy function
# called random.choice to generate 10 random indices out of a total
# of diameter.size indices. Then I create smaller sample vectors that
# are just 10 in size from the complete dataset
np.random.seed(10)
print('Total dataset has ',diameter.size,' data points')
sample_size = 10
print('Will use a random sample of only ',sample_size,' data points')
sample_indices = np.random.choice(diameter.size,sample_size)
diameter_sample = diameter[sample_indices]
mass_observed_sample = mass_observed[sample_indices]

# Set the degree of the polynomial you wish for your model
# degree_of_polynomial_to_fit = 1 is a linear model y = a x + b
# degree_of_polynomial_to_fit = 2 is a quadratic model y = a x^2 + b x + c
# degree_of_polynomial_to_fit = 3 is a cubic model y = a x^3 + b x^2 + c x + d
# etc.

degree_of_polynomial_to_fit = 1

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Total dataset has  4177  data points
# Will use a random sample of only  10  data points
# Fitted model is  1 st order
# y =
#
# 5.411 x - 1.368

# %% [markdown]
# For 1st degree polynomial looks to be underfitting which fails to learn the underlying relationship between inputs and outputs.

# %% [markdown]
# # 2nd degree polynomial

# %%
degree_of_polynomial_to_fit = 2

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  2 nd order
# y =
#        2
# 4.535 x + 1.648 x - 0.6226

# %% [markdown]
# 2nd degree polynomial looks to be underfitting also.

# %% [markdown]
# # 3rd degree polynomial

# %%
degree_of_polynomial_to_fit = 3

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  3 rd order
# y =
#         3         2
# -344.5 x + 419.2 x - 160.5 x + 19.98

# %% [markdown]
# 3rd degree polynomial looks to be underfitting as well.

# %% [markdown]
# # 4th degree polynomial

# %%
degree_of_polynomial_to_fit = 4

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  4 th order
# y =
#        4        3        2
# -3637 x + 5588 x - 3151 x + 777.3 x - 70.68

# %% [markdown]
# 4th degree polynomial looks to be fitting which means it is the best fit for this data and there is a relationship found.

# %% [markdown]
# # 5th degree polynomial

# %%
degree_of_polynomial_to_fit = 5

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  5 th order
# y =
#             5             4             3        2
# -1.715e+04 x + 3.103e+04 x - 2.208e+04 x + 7748 x - 1340 x + 91.67

# %% [markdown]
# 5th degree polynomial looks to be a good fit too

# %% [markdown]
# # 6th degree polynomial

# %%
degree_of_polynomial_to_fit = 6

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  6 th order
# y =
#            6            5             4             3             2
# 1.557e+05 x - 4.02e+05 x + 4.234e+05 x - 2.333e+05 x + 7.103e+04 x - 1.134e+04 x + 743.2

# %% [markdown]
# 6th degree polynomial looks to be a good fit.

# %% [markdown]
# # 7th degree polynomial

# %%
degree_of_polynomial_to_fit = 7

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  7 th order
# y =
#             7            6             5             4             3
# -1.103e+07 x + 3.18e+07 x - 3.901e+07 x + 2.638e+07 x - 1.062e+07 x
#               2
#  + 2.543e+06 x - 3.354e+05 x + 1.879e+04

# %% [markdown]
# 7th degree polynomial is overfitting which means their is noise and is too complex in comparison to the number of observations being used.

# %% [markdown]
# # 8th degree polynomial

# %%
degree_of_polynomial_to_fit = 8

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  8 th order
# y =
#             8             7             6             5             4
# -4.776e+08 x + 1.587e+09 x - 2.293e+09 x + 1.881e+09 x - 9.577e+08 x
#             3             2
#  + 3.1e+08 x - 6.228e+07 x + 7.098e+06 x - 3.514e+05

# %% [markdown]
# 8th degree polynomial is overfitting.

# %% [markdown]
# # 9th degree polynomial

# %%
degree_of_polynomial_to_fit = 9

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  9 th order
# y =
#            9             8             7             6             5
# -6.24e+10 x + 2.335e+11 x - 3.862e+11 x + 3.707e+11 x - 2.274e+11 x
#              4             3             2
#  + 9.25e+10 x - 2.494e+10 x + 4.296e+09 x - 4.293e+08 x + 1.895e+07

# %% [markdown]
# 9th degree polynomial is overfitting

# %% [markdown]
# # 10th degree polynomial

# %%
degree_of_polynomial_to_fit = 10

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100) # have 100 points with min and max

# Use the fitted model coefficients to create the model function
model_for_mass = np.poly1d(coefficients) # created the model for the poly 1 degree
# output will be 2 # y = mass x =  diameter

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Now I can do the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')

#plt.text(0.05,2.2,str(loss))
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')

plt.savefig("abalone.png")
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit == 3:
    s='rd order'
elif degree_of_polynomial_to_fit == 4:
    s='th order'
elif degree_of_polynomial_to_fit == 5:
    s='th order'
elif degree_of_polynomial_to_fit == 6:
    s='th order'
elif degree_of_polynomial_to_fit == 7:
    s='th order'
elif degree_of_polynomial_to_fit == 8:
    s='th order'    
elif degree_of_polynomial_to_fit == 9:
    s='th order'    
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# /home/ktd2001/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RankWarning: Polyfit may be poorly conditioned
# Fitted model is  10 th order
# y =
#             10             9             8             7             6
# -6.043e+10 x  + 1.954e+11 x - 2.589e+11 x + 1.685e+11 x - 3.753e+10 x
#              5             4             3           2
#  - 2.25e+10 x + 2.142e+10 x - 8.121e+09 x + 1.7e+09 x - 1.929e+08 x + 9.322e+06

# %% [markdown]
# 10th degree polynomial is overfitting

# %% [markdown]
# # Reflection

# %% [markdown]
# 1-3 degree polynomials are underfitting.
# 4-6 degree polynomials are fitting.
# 7-10 degree polynomials are overfitting.
